# %% [markdown]
# ## Importing the Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Sigmoid Function

# %%
def sigmoid(z):
    x = 1/(1+np.exp(-z))
    return x

# %%
sigmoid(np.array([0,2]))
# Out:
# array([ 0.5       ,  0.88079708])

# %% [markdown]
# ## Initialize w,b

# %%
def initialize_with_zeros(dim):
    w = np.zeros(shape=(dim,1))
    b = 0
    return w,b

# %%
initialize_with_zeros(2)
# Out:
# (array([[ 0.],
#         [ 0.]]), 0)

# %% [markdown]
# ## Forward Propagation

# %%
def propagate(w,b,X,Y):
    m = X.shape[1]
    A = sigmoid(np.dot(w.T,X)+b)
    cost = -1/m * np.sum((Y*np.log(A)+(1-Y)*np.log(1-A)))
    dw = 1/m*np.dot(X,(A-Y).T)
    db = 1/m*np.sum(A-Y)
    cost = np.squeeze(cost)
    grads = {'dw':dw,'db':db}
    return grads,cost

# %%
w, b, X, Y = np.array([[1.],[2.]]), 2., np.array([[1.,2.,-1.],[3.,4.,-3.2]]), np.array([[1,0,1]])
grads,cost = propagate(w,b,X,Y)
print('w: ' + str(grads['dw']))
print('\n')
print('b: ' + str(grads['db']))
print('\n')
print('cost: ' + str(cost))
# Out:
# w: [[ 0.99845601]
#  [ 2.39507239]]
#
#
# b: 0.00145557813678
#
#
# cost: 5.80154531939

# %% [markdown]
# ## Optimizing using Gradient Descent

# %%
def optimize(w,b,X,Y,num_iterations,learning_rate,print_cost):
    costs = []
    for i in range(num_iterations):
        grads,cost = propagate(w,b,X,Y)
        dw = grads['dw']
        db = grads['db']
        w = w - learning_rate*dw
        b = b - learning_rate*db
        if i % 100 == 0:
            costs.append(cost)
        if (i % 100 == 0 and print_cost == True):
            print("Cost at iteration %d:%f"%(i,cost))
        grads = {'dw':dw,'db':db}
        params = {'w':w,'b':b}
    return grads,params,costs

# %%
w, b, X, Y = np.array([[1.],[2.]]), 2., np.array([[1.,2.,-1.],[3.,4.,-3.2]]), np.array([[1,0,1]])
grads,params, costs = optimize(w, b, X, Y, num_iterations= 100000, learning_rate = 0.009, print_cost = True)
# Out:
# Cost at iteration 0:5.801545
# Cost at iteration 100:1.055933
# Cost at iteration 200:0.378303
# Cost at iteration 300:0.363595
# Cost at iteration 400:0.356242
# Cost at iteration 500:0.349210
# Cost at iteration 600:0.342420
# Cost at iteration 700:0.335860
# Cost at iteration 800:0.329517
# Cost at iteration 900:0.323380
# Cost at iteration 1000:0.317438
# Cost at iteration 1100:0.311683
# Cost at iteration 1200:0.306106
# Cost at iteration 1300:0.300699
# Cost at iteration 1400:0.295454
# Cost at iteration 1500:0.290364
# Cost at iteration 1600:0.285423
# Cost at iteration 1700:0.280624
# Cost at iteration 1800:0.275962
# Cost at iteration 1900:0.271432
# Cost at iteration 2000:0.267027
# Cost at iteration 2100:0.262744
# Cost at iteration 2200:0.258577
# Cost at iteration 2300:0.254523
# Cost at iteration 2400:0.250576
# Cost at iteration 2500:0.246734
# Cost at iteration 2600:0.242992
# Cost at iteration 2700:0.239346
# Cost at iteration 2800:0.235794
# Cost at iteration 2900:0.232332
# Cost at iteration 3000:0.228957
# Cost at iteration 3100:0.225666
# Cost at iteration 3200:0.222455
# Cost at iteration 3300:0.219324
# Cost at iteration 3400:0.216267
# Cost at iteration 3500:0.213285
# Cost at iteration 3600:0.210373
# Cost at iteration 3700:0.207529
# Cost at iteration 3800:0.204752
# Cost at iteration 3900:0.202040
# Cost at iteration 4000:0.199389
# Cost at iteration 4100:0.196799
# Cost at iteration 4200:0.194267
# Cost at iteration 4300:0.191792
# Cost at iteration 4400:0.189371
# Cost at iteration 4500:0.187004
# Cost at iteration 4600:0.184689
# Cost at iteration 4700:0.182424
# Cost at iteration 4800:0.180207
# Cost at iteration 4900:0.178037
# Cost at iteration 5000:0.175913
# Cost at iteration 5100:0.173834
# Cost at iteration 5200:0.171798
# Cost at iteration 5300:0.169804
# Cost at iteration 5400:0.167851
# Cost at iteration 5500:0.165937
# Cost at iteration 5600:0.164062
# Cost at iteration 5700:0.162224
# Cost at iteration 5800:0.160423
# Cost at iteration 5900:0.158657
# Cost at iteration 6000:0.156926
# Cost at iteration 6100:0.155228
# Cost at iteration 6200:0.153563
# Cost at iteration 6300:0.151930
# Cost at iteration 6400:0.150328
# Cost at iteration 6500:0.148755
# Cost at iteration 6600:0.147213
# Cost at iteration 6700:0.145698
# Cost at iteration 6800:0.144212
# Cost at iteration 6900:0.142753
# Cost at iteration 7000:0.141320
# Cost at iteration 7100:0.139913
# Cost at iteration 7200:0.138531
# Cost at iteration 7300:0.137174
# Cost at iteration 7400:0.135841
# Cost at iteration 7500:0.134531
# Cost at iteration 7600:0.133244
# Cost at iteration 7700:0.131979
# Cost at iteration 7800:0.130735
# Cost at iteration 7900:0.129513
# Cost at iteration 8000:0.128312
# Cost at iteration 8100:0.127130
# Cost at iteration 8200:0.125969
# Cost at iteration 8300:0.124826
# Cost at iteration 8400:0.123703
# Cost at iteration 8500:0.122598
# Cost at iteration 8600:0.121510
# Cost at iteration 8700:0.120441
# Cost at iteration 8800:0.119388
# Cost at iteration 8900:0.118352
# Cost at iteration 9000:0.117333
# Cost at iteration 9100:0.116330
# Cost at iteration 9200:0.115342
# Cost at iteration 9300:0.114369
# Cost at iteration 9400:0.113412
# Cost at iteration 9500:0.112469
# Cost at iteration 9600:0.111541
# Cost at iteration 9700:0.110626
# Cost at iteration 9800:0.109726
# Cost at iteration 9900:0.108839
# Cost at iteration 10000:0.107965
# Cost at iteration 10100:0.107103
# Cost at iteration 10200:0.106255
# Cost at iteration 10300:0.105419
# Cost at iteration 10400:0.104595
# Cost at iteration 10500:0.103783
# Cost at iteration 10600:0.102982
# Cost at iteration 10700:0.102193
# Cost at iteration 10800:0.101415
# Cost at iteration 10900:0.100648
# Cost at iteration 11000:0.099891
# Cost at iteration 11100:0.099145
# Cost at iteration 11200:0.098410
# Cost at iteration 11300:0.097684
# Cost at iteration 11400:0.096969
# Cost at iteration 11500:0.096263
# Cost at iteration 11600:0.095567
# Cost at iteration 11700:0.094879
# Cost at iteration 11800:0.094202
# Cost at iteration 11900:0.093533
# Cost at iteration 12000:0.092873
# Cost at iteration 12100:0.092221
# Cost at iteration 12200:0.091578
# Cost at iteration 12300:0.090944
# Cost at iteration 12400:0.090317
# Cost at iteration 12500:0.089699
# Cost at iteration 12600:0.089088
# Cost at iteration 12700:0.088486
# Cost at iteration 12800:0.087890
# Cost at iteration 12900:0.087303
# Cost at iteration 13000:0.086722
# Cost at iteration 13100:0.086149
# Cost at iteration 13200:0.085583
# Cost at iteration 13300:0.085024
# Cost at iteration 13400:0.084472
# Cost at iteration 13500:0.083926
# Cost at iteration 13600:0.083387
# Cost at iteration 13700:0.082854
# Cost at iteration 13800:0.082328
# Cost at iteration 13900:0.081808
# Cost at iteration 14000:0.081294
# Cost at iteration 14100:0.080787
# Cost at iteration 14200:0.080285
# Cost at iteration 14300:0.079789
# Cost at iteration 14400:0.079299
# Cost at iteration 14500:0.078814
# Cost at iteration 14600:0.078335
# Cost at iteration 14700:0.077862
# Cost at iteration 14800:0.077393
# Cost at iteration 14900:0.076931
# Cost at iteration 15000:0.076473
# Cost at iteration 15100:0.076020
# Cost at iteration 15200:0.075573
# Cost at iteration 15300:0.075130
# Cost at iteration 15400:0.074693
# Cost at iteration 15500:0.074260
# Cost at iteration 15600:0.073832
# Cost at iteration 15700:0.073408
# Cost at iteration 15800:0.072989
# Cost at iteration 15900:0.072575
# Cost at iteration 16000:0.072165
# Cost at iteration 16100:0.071759
# Cost at iteration 16200:0.071358
# Cost at iteration 16300:0.070961
# Cost at iteration 16400:0.070568
# Cost at iteration 16500:0.070179
# Cost at iteration 16600:0.069794
# Cost at iteration 16700:0.069414
# Cost at iteration 16800:0.069037
# Cost at iteration 16900:0.068664
# Cost at iteration 17000:0.068295
# Cost at iteration 17100:0.067929
# Cost at iteration 17200:0.067568
# Cost at iteration 17300:0.067210
# Cost at iteration 17400:0.066855
# Cost at iteration 17500:0.066504
# Cost at iteration 17600:0.066157
# Cost at iteration 17700:0.065813
# Cost at iteration 17800:0.065472
# Cost at iteration 17900:0.065135
# Cost at iteration 18000:0.064801
# Cost at iteration 18100:0.064470
# Cost at iteration 18200:0.064143
# Cost at iteration 18300:0.063819
# Cost at iteration 18400:0.063497
# Cost at iteration 18500:0.063179
# Cost at iteration 18600:0.062864
# Cost at iteration 18700:0.062552
# Cost at iteration 18800:0.062243
# Cost at iteration 18900:0.061936
# Cost at iteration 19000:0.061633
# Cost at iteration 19100:0.061332
# Cost at iteration 19200:0.061035
# Cost at iteration 19300:0.060740
# Cost at iteration 19400:0.060447
# Cost at iteration 19500:0.060158
# Cost at iteration 19600:0.059871
# Cost at iteration 19700:0.059586
# Cost at iteration 19800:0.059304
# Cost at iteration 19900:0.059025
# Cost at iteration 20000:0.058748
# Cost at iteration 20100:0.058474
# Cost at iteration 20200:0.058202
# Cost at iteration 20300:0.057933
# Cost at iteration 20400:0.057666
# Cost at iteration 20500:0.057401
# Cost at iteration 20600:0.057138
# Cost at iteration 20700:0.056878
# Cost at iteration 20800:0.056620
# Cost at iteration 20900:0.056365
# Cost at iteration 21000:0.056111
# Cost at iteration 21100:0.055860
# Cost at iteration 21200:0.055611
# Cost at iteration 21300:0.055364
# Cost at iteration 21400:0.055119
# Cost at iteration 21500:0.054876
# Cost at iteration 21600:0.054636
# Cost at iteration 21700:0.054397
# Cost at iteration 21800:0.054160
# Cost at iteration 21900:0.053925
# Cost at iteration 22000:0.053693
# Cost at iteration 22100:0.053462
# Cost at iteration 22200:0.053233
# Cost at iteration 22300:0.053006
# Cost at iteration 22400:0.052780
# Cost at iteration 22500:0.052557
# Cost at iteration 22600:0.052335
# Cost at iteration 22700:0.052115
# Cost at iteration 22800:0.051897
# Cost at iteration 22900:0.051681
# Cost at iteration 23000:0.051467
# Cost at iteration 23100:0.051254
# Cost at iteration 23200:0.051043
# Cost at iteration 23300:0.050833
# Cost at iteration 23400:0.050625
# Cost at iteration 23500:0.050419
# Cost at iteration 23600:0.050214
# Cost at iteration 23700:0.050011
# Cost at iteration 23800:0.049810
# Cost at iteration 23900:0.049610
# Cost at iteration 24000:0.049412
# Cost at iteration 24100:0.049215
# Cost at iteration 24200:0.049019
# Cost at iteration 24300:0.048826
# Cost at iteration 24400:0.048633
# Cost at iteration 24500:0.048442
# Cost at iteration 24600:0.048253
# Cost at iteration 24700:0.048065
# Cost at iteration 24800:0.047878
# Cost at iteration 24900:0.047693
# Cost at iteration 25000:0.047509
# Cost at iteration 25100:0.047327
# Cost at iteration 25200:0.047145
# Cost at iteration 25300:0.046966
# Cost at iteration 25400:0.046787
# Cost at iteration 25500:0.046610
# Cost at iteration 25600:0.046434
# Cost at iteration 25700:0.046259
# Cost at iteration 25800:0.046086
# Cost at iteration 25900:0.045914
# Cost at iteration 26000:0.045743
# Cost at iteration 26100:0.045573
# Cost at iteration 26200:0.045405
# Cost at iteration 26300:0.045238
# Cost at iteration 26400:0.045072
# Cost at iteration 26500:0.044907
# Cost at iteration 26600:0.044743
# Cost at iteration 26700:0.044581
# Cost at iteration 26800:0.044419
# Cost at iteration 26900:0.044259
# Cost at iteration 27000:0.044100
# Cost at iteration 27100:0.043942
# Cost at iteration 27200:0.043785
# Cost at iteration 27300:0.043629
# Cost at iteration 27400:0.043474
# Cost at iteration 27500:0.043320
# Cost at iteration 27600:0.043168
# Cost at iteration 27700:0.043016
# Cost at iteration 27800:0.042865
# Cost at iteration 27900:0.042716
# Cost at iteration 28000:0.042567
# Cost at iteration 28100:0.042419
# Cost at iteration 28200:0.042273
# Cost at iteration 28300:0.042127
# Cost at iteration 28400:0.041982
# Cost at iteration 28500:0.041839
# Cost at iteration 28600:0.041696
# Cost at iteration 28700:0.041554
# Cost at iteration 28800:0.041413
# Cost at iteration 28900:0.041273
# Cost at iteration 29000:0.041134
# Cost at iteration 29100:0.040996
# Cost at iteration 29200:0.040859
# Cost at iteration 29300:0.040722
# Cost at iteration 29400:0.040587
# Cost at iteration 29500:0.040452
# Cost at iteration 29600:0.040319
# Cost at iteration 29700:0.040186
# Cost at iteration 29800:0.040054
# Cost at iteration 29900:0.039922
# Cost at iteration 30000:0.039792
# Cost at iteration 30100:0.039662
# Cost at iteration 30200:0.039534
# Cost at iteration 30300:0.039406
# Cost at iteration 30400:0.039279
# Cost at iteration 30500:0.039152
# Cost at iteration 30600:0.039027
# Cost at iteration 30700:0.038902
# Cost at iteration 30800:0.038778
# Cost at iteration 30900:0.038655
# Cost at iteration 31000:0.038532
# Cost at iteration 31100:0.038411
# Cost at iteration 31200:0.038290
# Cost at iteration 31300:0.038169
# Cost at iteration 31400:0.038050
# Cost at iteration 31500:0.037931
# Cost at iteration 31600:0.037813
# Cost at iteration 31700:0.037696
# Cost at iteration 31800:0.037579
# Cost at iteration 31900:0.037463
# Cost at iteration 32000:0.037348
# Cost at iteration 32100:0.037233
# Cost at iteration 32200:0.037120
# Cost at iteration 32300:0.037006
# Cost at iteration 32400:0.036894
# Cost at iteration 32500:0.036782
# Cost at iteration 32600:0.036671
# Cost at iteration 32700:0.036560
# Cost at iteration 32800:0.036450
# Cost at iteration 32900:0.036341
# Cost at iteration 33000:0.036232
# Cost at iteration 33100:0.036124
# Cost at iteration 33200:0.036017
# Cost at iteration 33300:0.035910
# Cost at iteration 33400:0.035804
# Cost at iteration 33500:0.035699
# Cost at iteration 33600:0.035594
# Cost at iteration 33700:0.035489
# Cost at iteration 33800:0.035386
# Cost at iteration 33900:0.035282
# Cost at iteration 34000:0.035180
# Cost at iteration 34100:0.035078
# Cost at iteration 34200:0.034976
# Cost at iteration 34300:0.034876
# Cost at iteration 34400:0.034775
# Cost at iteration 34500:0.034676
# Cost at iteration 34600:0.034576
# Cost at iteration 34700:0.034478
# Cost at iteration 34800:0.034380
# Cost at iteration 34900:0.034282
# Cost at iteration 35000:0.034185
# Cost at iteration 35100:0.034089
# Cost at iteration 35200:0.033993
# Cost at iteration 35300:0.033898
# Cost at iteration 35400:0.033803
# Cost at iteration 35500:0.033708
# Cost at iteration 35600:0.033614
# Cost at iteration 35700:0.033521
# Cost at iteration 35800:0.033428
# Cost at iteration 35900:0.033336
# Cost at iteration 36000:0.033244
# Cost at iteration 36100:0.033153
# Cost at iteration 36200:0.033062
# Cost at iteration 36300:0.032972
# Cost at iteration 36400:0.032882
# Cost at iteration 36500:0.032792
# Cost at iteration 36600:0.032703
# Cost at iteration 36700:0.032615
# Cost at iteration 36800:0.032527
# Cost at iteration 36900:0.032439
# Cost at iteration 37000:0.032352
# Cost at iteration 37100:0.032266
# Cost at iteration 37200:0.032179
# Cost at iteration 37300:0.032094
# Cost at iteration 37400:0.032008
# Cost at iteration 37500:0.031924
# Cost at iteration 37600:0.031839
# Cost at iteration 37700:0.031755
# Cost at iteration 37800:0.031672
# Cost at iteration 37900:0.031589
# Cost at iteration 38000:0.031506
# Cost at iteration 38100:0.031424
# Cost at iteration 38200:0.031342
# Cost at iteration 38300:0.031260
# Cost at iteration 38400:0.031179
# Cost at iteration 38500:0.031099
# Cost at iteration 38600:0.031018
# Cost at iteration 38700:0.030939
# Cost at iteration 38800:0.030859
# Cost at iteration 38900:0.030780
# Cost at iteration 39000:0.030702
# Cost at iteration 39100:0.030623
# Cost at iteration 39200:0.030546
# Cost at iteration 39300:0.030468
# Cost at iteration 39400:0.030391
# Cost at iteration 39500:0.030314
# Cost at iteration 39600:0.030238
# Cost at iteration 39700:0.030162
# Cost at iteration 39800:0.030087
# Cost at iteration 39900:0.030011
# Cost at iteration 40000:0.029937
# Cost at iteration 40100:0.029862
# Cost at iteration 40200:0.029788
# Cost at iteration 40300:0.029714
# Cost at iteration 40400:0.029641
# Cost at iteration 40500:0.029568
# Cost at iteration 40600:0.029495
# Cost at iteration 40700:0.029423
# Cost at iteration 40800:0.029351
# Cost at iteration 40900:0.029279
# Cost at iteration 41000:0.029208
# Cost at iteration 41100:0.029137
# Cost at iteration 41200:0.029066
# Cost at iteration 41300:0.028996
# Cost at iteration 41400:0.028926
# Cost at iteration 41500:0.028857
# Cost at iteration 41600:0.028787
# Cost at iteration 41700:0.028718
# Cost at iteration 41800:0.028650
# Cost at iteration 41900:0.028581
# Cost at iteration 42000:0.028513
# Cost at iteration 42100:0.028446
# Cost at iteration 42200:0.028378
# Cost at iteration 42300:0.028311
# Cost at iteration 42400:0.028244
# Cost at iteration 42500:0.028178
# Cost at iteration 42600:0.028112
# Cost at iteration 42700:0.028046
# Cost at iteration 42800:0.027981
# Cost at iteration 42900:0.027915
# Cost at iteration 43000:0.027850
# Cost at iteration 43100:0.027786
# Cost at iteration 43200:0.027721
# Cost at iteration 43300:0.027657
# Cost at iteration 43400:0.027593
# Cost at iteration 43500:0.027530
# Cost at iteration 43600:0.027467
# Cost at iteration 43700:0.027404
# Cost at iteration 43800:0.027341
# Cost at iteration 43900:0.027279
# Cost at iteration 44000:0.027217
# Cost at iteration 44100:0.027155
# Cost at iteration 44200:0.027093
# Cost at iteration 44300:0.027032
# Cost at iteration 44400:0.026971
# Cost at iteration 44500:0.026911
# Cost at iteration 44600:0.026850
# Cost at iteration 44700:0.026790
# Cost at iteration 44800:0.026730
# Cost at iteration 44900:0.026670
# Cost at iteration 45000:0.026611
# Cost at iteration 45100:0.026552
# Cost at iteration 45200:0.026493
# Cost at iteration 45300:0.026434
# Cost at iteration 45400:0.026376
# Cost at iteration 45500:0.026318
# Cost at iteration 45600:0.026260
# Cost at iteration 45700:0.026202
# Cost at iteration 45800:0.026145
# Cost at iteration 45900:0.026088
# Cost at iteration 46000:0.026031
# Cost at iteration 46100:0.025974
# Cost at iteration 46200:0.025918
# Cost at iteration 46300:0.025862
# Cost at iteration 46400:0.025806
# Cost at iteration 46500:0.025750
# Cost at iteration 46600:0.025695
# Cost at iteration 46700:0.025639
# Cost at iteration 46800:0.025585
# Cost at iteration 46900:0.025530
# Cost at iteration 47000:0.025475
# Cost at iteration 47100:0.025421
# Cost at iteration 47200:0.025367
# Cost at iteration 47300:0.025313
# Cost at iteration 47400:0.025259
# Cost at iteration 47500:0.025206
# Cost at iteration 47600:0.025153
# Cost at iteration 47700:0.025100
# Cost at iteration 47800:0.025047
# Cost at iteration 47900:0.024995
# Cost at iteration 48000:0.024942
# Cost at iteration 48100:0.024890
# Cost at iteration 48200:0.024838
# Cost at iteration 48300:0.024787
# Cost at iteration 48400:0.024735
# Cost at iteration 48500:0.024684
# Cost at iteration 48600:0.024633
# Cost at iteration 48700:0.024582
# Cost at iteration 48800:0.024532
# Cost at iteration 48900:0.024481
# Cost at iteration 49000:0.024431
# Cost at iteration 49100:0.024381
# Cost at iteration 49200:0.024331
# Cost at iteration 49300:0.024281
# Cost at iteration 49400:0.024232
# Cost at iteration 49500:0.024183
# Cost at iteration 49600:0.024134
# Cost at iteration 49700:0.024085
# Cost at iteration 49800:0.024036
# Cost at iteration 49900:0.023988
# Cost at iteration 50000:0.023940
# Cost at iteration 50100:0.023892
# Cost at iteration 50200:0.023844
# Cost at iteration 50300:0.023796
# Cost at iteration 50400:0.023749
# Cost at iteration 50500:0.023701
# Cost at iteration 50600:0.023654
# Cost at iteration 50700:0.023607
# Cost at iteration 50800:0.023560
# Cost at iteration 50900:0.023514
# Cost at iteration 51000:0.023467
# Cost at iteration 51100:0.023421
# Cost at iteration 51200:0.023375
# Cost at iteration 51300:0.023329
# Cost at iteration 51400:0.023284
# Cost at iteration 51500:0.023238
# Cost at iteration 51600:0.023193
# Cost at iteration 51700:0.023148
# Cost at iteration 51800:0.023103
# Cost at iteration 51900:0.023058
# Cost at iteration 52000:0.023013
# Cost at iteration 52100:0.022969
# Cost at iteration 52200:0.022924
# Cost at iteration 52300:0.022880
# Cost at iteration 52400:0.022836
# Cost at iteration 52500:0.022792
# Cost at iteration 52600:0.022749
# Cost at iteration 52700:0.022705
# Cost at iteration 52800:0.022662
# Cost at iteration 52900:0.022619
# Cost at iteration 53000:0.022576
# Cost at iteration 53100:0.022533
# Cost at iteration 53200:0.022490
# Cost at iteration 53300:0.022448
# Cost at iteration 53400:0.022406
# Cost at iteration 53500:0.022363
# Cost at iteration 53600:0.022321
# Cost at iteration 53700:0.022279
# Cost at iteration 53800:0.022238
# Cost at iteration 53900:0.022196
# Cost at iteration 54000:0.022155
# Cost at iteration 54100:0.022113
# Cost at iteration 54200:0.022072
# Cost at iteration 54300:0.022031
# Cost at iteration 54400:0.021990
# Cost at iteration 54500:0.021950
# Cost at iteration 54600:0.021909
# Cost at iteration 54700:0.021869
# Cost at iteration 54800:0.021829
# Cost at iteration 54900:0.021789
# Cost at iteration 55000:0.021749
# Cost at iteration 55100:0.021709
# Cost at iteration 55200:0.021669
# Cost at iteration 55300:0.021630
# Cost at iteration 55400:0.021590
# Cost at iteration 55500:0.021551
# Cost at iteration 55600:0.021512
# Cost at iteration 55700:0.021473
# Cost at iteration 55800:0.021434
# Cost at iteration 55900:0.021395
# Cost at iteration 56000:0.021357
# Cost at iteration 56100:0.021319
# Cost at iteration 56200:0.021280
# Cost at iteration 56300:0.021242
# Cost at iteration 56400:0.021204
# Cost at iteration 56500:0.021166
# Cost at iteration 56600:0.021129
# Cost at iteration 56700:0.021091
# Cost at iteration 56800:0.021053
# Cost at iteration 56900:0.021016
# Cost at iteration 57000:0.020979
# Cost at iteration 57100:0.020942
# Cost at iteration 57200:0.020905
# Cost at iteration 57300:0.020868
# Cost at iteration 57400:0.020831
# Cost at iteration 57500:0.020795
# Cost at iteration 57600:0.020758
# Cost at iteration 57700:0.020722
# Cost at iteration 57800:0.020686
# Cost at iteration 57900:0.020650
# Cost at iteration 58000:0.020614
# Cost at iteration 58100:0.020578
# Cost at iteration 58200:0.020542
# Cost at iteration 58300:0.020507
# Cost at iteration 58400:0.020471
# Cost at iteration 58500:0.020436
# Cost at iteration 58600:0.020401
# Cost at iteration 58700:0.020366
# Cost at iteration 58800:0.020331
# Cost at iteration 58900:0.020296
# Cost at iteration 59000:0.020261
# Cost at iteration 59100:0.020226
# Cost at iteration 59200:0.020192
# Cost at iteration 59300:0.020158
# Cost at iteration 59400:0.020123
# Cost at iteration 59500:0.020089
# Cost at iteration 59600:0.020055
# Cost at iteration 59700:0.020021
# Cost at iteration 59800:0.019987
# Cost at iteration 59900:0.019954
# Cost at iteration 60000:0.019920
# Cost at iteration 60100:0.019887
# Cost at iteration 60200:0.019853
# Cost at iteration 60300:0.019820
# Cost at iteration 60400:0.019787
# Cost at iteration 60500:0.019754
# Cost at iteration 60600:0.019721
# Cost at iteration 60700:0.019688
# Cost at iteration 60800:0.019655
# Cost at iteration 60900:0.019623
# Cost at iteration 61000:0.019590
# Cost at iteration 61100:0.019558
# Cost at iteration 61200:0.019525
# Cost at iteration 61300:0.019493
# Cost at iteration 61400:0.019461
# Cost at iteration 61500:0.019429
# Cost at iteration 61600:0.019397
# Cost at iteration 61700:0.019365
# Cost at iteration 61800:0.019334
# Cost at iteration 61900:0.019302
# Cost at iteration 62000:0.019271
# Cost at iteration 62100:0.019239
# Cost at iteration 62200:0.019208
# Cost at iteration 62300:0.019177
# Cost at iteration 62400:0.019146
# Cost at iteration 62500:0.019115
# Cost at iteration 62600:0.019084
# Cost at iteration 62700:0.019053
# Cost at iteration 62800:0.019023
# Cost at iteration 62900:0.018992
# Cost at iteration 63000:0.018961
# Cost at iteration 63100:0.018931
# Cost at iteration 63200:0.018901
# Cost at iteration 63300:0.018871
# Cost at iteration 63400:0.018841
# Cost at iteration 63500:0.018810
# Cost at iteration 63600:0.018781
# Cost at iteration 63700:0.018751
# Cost at iteration 63800:0.018721
# Cost at iteration 63900:0.018691
# Cost at iteration 64000:0.018662
# Cost at iteration 64100:0.018632
# Cost at iteration 64200:0.018603
# Cost at iteration 64300:0.018574
# Cost at iteration 64400:0.018545
# Cost at iteration 64500:0.018516
# Cost at iteration 64600:0.018487
# Cost at iteration 64700:0.018458
# Cost at iteration 64800:0.018429
# Cost at iteration 64900:0.018400
# Cost at iteration 65000:0.018371
# Cost at iteration 65100:0.018343
# Cost at iteration 65200:0.018314
# Cost at iteration 65300:0.018286
# Cost at iteration 65400:0.018258
# Cost at iteration 65500:0.018230
# Cost at iteration 65600:0.018201
# Cost at iteration 65700:0.018173
# Cost at iteration 65800:0.018145
# Cost at iteration 65900:0.018118
# Cost at iteration 66000:0.018090
# Cost at iteration 66100:0.018062
# Cost at iteration 66200:0.018035
# Cost at iteration 66300:0.018007
# Cost at iteration 66400:0.017980
# Cost at iteration 66500:0.017952
# Cost at iteration 66600:0.017925
# Cost at iteration 66700:0.017898
# Cost at iteration 66800:0.017871
# Cost at iteration 66900:0.017844
# Cost at iteration 67000:0.017817
# Cost at iteration 67100:0.017790
# Cost at iteration 67200:0.017763
# Cost at iteration 67300:0.017736
# Cost at iteration 67400:0.017710
# Cost at iteration 67500:0.017683
# Cost at iteration 67600:0.017657
# Cost at iteration 67700:0.017630
# Cost at iteration 67800:0.017604
# Cost at iteration 67900:0.017578
# Cost at iteration 68000:0.017551
# Cost at iteration 68100:0.017525
# Cost at iteration 68200:0.017499
# Cost at iteration 68300:0.017473
# Cost at iteration 68400:0.017447
# Cost at iteration 68500:0.017422
# Cost at iteration 68600:0.017396
# Cost at iteration 68700:0.017370
# Cost at iteration 68800:0.017345
# Cost at iteration 68900:0.017319
# Cost at iteration 69000:0.017294
# Cost at iteration 69100:0.017269
# Cost at iteration 69200:0.017243
# Cost at iteration 69300:0.017218
# Cost at iteration 69400:0.017193
# Cost at iteration 69500:0.017168
# Cost at iteration 69600:0.017143
# Cost at iteration 69700:0.017118
# Cost at iteration 69800:0.017093
# Cost at iteration 69900:0.017068
# Cost at iteration 70000:0.017044
# Cost at iteration 70100:0.017019
# Cost at iteration 70200:0.016995
# Cost at iteration 70300:0.016970
# Cost at iteration 70400:0.016946
# Cost at iteration 70500:0.016921
# Cost at iteration 70600:0.016897
# Cost at iteration 70700:0.016873
# Cost at iteration 70800:0.016849
# Cost at iteration 70900:0.016825
# Cost at iteration 71000:0.016801
# Cost at iteration 71100:0.016777
# Cost at iteration 71200:0.016753
# Cost at iteration 71300:0.016729
# Cost at iteration 71400:0.016705
# Cost at iteration 71500:0.016682
# Cost at iteration 71600:0.016658
# Cost at iteration 71700:0.016634
# Cost at iteration 71800:0.016611
# Cost at iteration 71900:0.016588
# Cost at iteration 72000:0.016564
# Cost at iteration 72100:0.016541
# Cost at iteration 72200:0.016518
# Cost at iteration 72300:0.016495
# Cost at iteration 72400:0.016471
# Cost at iteration 72500:0.016448
# Cost at iteration 72600:0.016425
# Cost at iteration 72700:0.016403
# Cost at iteration 72800:0.016380
# Cost at iteration 72900:0.016357
# Cost at iteration 73000:0.016334
# Cost at iteration 73100:0.016312
# Cost at iteration 73200:0.016289
# Cost at iteration 73300:0.016267
# Cost at iteration 73400:0.016244
# Cost at iteration 73500:0.016222
# Cost at iteration 73600:0.016199
# Cost at iteration 73700:0.016177
# Cost at iteration 73800:0.016155
# Cost at iteration 73900:0.016133
# Cost at iteration 74000:0.016111
# Cost at iteration 74100:0.016089
# Cost at iteration 74200:0.016067
# Cost at iteration 74300:0.016045
# Cost at iteration 74400:0.016023
# Cost at iteration 74500:0.016001
# Cost at iteration 74600:0.015979
# Cost at iteration 74700:0.015958
# Cost at iteration 74800:0.015936
# Cost at iteration 74900:0.015914
# Cost at iteration 75000:0.015893
# Cost at iteration 75100:0.015871
# Cost at iteration 75200:0.015850
# Cost at iteration 75300:0.015829
# Cost at iteration 75400:0.015807
# Cost at iteration 75500:0.015786
# Cost at iteration 75600:0.015765
# Cost at iteration 75700:0.015744
# Cost at iteration 75800:0.015723
# Cost at iteration 75900:0.015702
# Cost at iteration 76000:0.015681
# Cost at iteration 76100:0.015660
# Cost at iteration 76200:0.015639
# Cost at iteration 76300:0.015618
# Cost at iteration 76400:0.015598
# Cost at iteration 76500:0.015577
# Cost at iteration 76600:0.015556
# Cost at iteration 76700:0.015536
# Cost at iteration 76800:0.015515
# Cost at iteration 76900:0.015495
# Cost at iteration 77000:0.015475
# Cost at iteration 77100:0.015454
# Cost at iteration 77200:0.015434
# Cost at iteration 77300:0.015414
# Cost at iteration 77400:0.015393
# Cost at iteration 77500:0.015373
# Cost at iteration 77600:0.015353
# Cost at iteration 77700:0.015333
# Cost at iteration 77800:0.015313
# Cost at iteration 77900:0.015293
# Cost at iteration 78000:0.015273
# Cost at iteration 78100:0.015254
# Cost at iteration 78200:0.015234
# Cost at iteration 78300:0.015214
# Cost at iteration 78400:0.015194
# Cost at iteration 78500:0.015175
# Cost at iteration 78600:0.015155
# Cost at iteration 78700:0.015136
# Cost at iteration 78800:0.015116
# Cost at iteration 78900:0.015097
# Cost at iteration 79000:0.015077
# Cost at iteration 79100:0.015058
# Cost at iteration 79200:0.015039
# Cost at iteration 79300:0.015019
# Cost at iteration 79400:0.015000
# Cost at iteration 79500:0.014981
# Cost at iteration 79600:0.014962
# Cost at iteration 79700:0.014943
# Cost at iteration 79800:0.014924
# Cost at iteration 79900:0.014905
# Cost at iteration 80000:0.014886
# Cost at iteration 80100:0.014867
# Cost at iteration 80200:0.014849
# Cost at iteration 80300:0.014830
# Cost at iteration 80400:0.014811
# Cost at iteration 80500:0.014792
# Cost at iteration 80600:0.014774
# Cost at iteration 80700:0.014755
# Cost at iteration 80800:0.014737
# Cost at iteration 80900:0.014718
# Cost at iteration 81000:0.014700
# Cost at iteration 81100:0.014681
# Cost at iteration 81200:0.014663
# Cost at iteration 81300:0.014645
# Cost at iteration 81400:0.014627
# Cost at iteration 81500:0.014608
# Cost at iteration 81600:0.014590
# Cost at iteration 81700:0.014572
# Cost at iteration 81800:0.014554
# Cost at iteration 81900:0.014536
# Cost at iteration 82000:0.014518
# Cost at iteration 82100:0.014500
# Cost at iteration 82200:0.014482
# Cost at iteration 82300:0.014464
# Cost at iteration 82400:0.014447
# Cost at iteration 82500:0.014429
# Cost at iteration 82600:0.014411
# Cost at iteration 82700:0.014393
# Cost at iteration 82800:0.014376
# Cost at iteration 82900:0.014358
# Cost at iteration 83000:0.014341
# Cost at iteration 83100:0.014323
# Cost at iteration 83200:0.014306
# Cost at iteration 83300:0.014288
# Cost at iteration 83400:0.014271
# Cost at iteration 83500:0.014253
# Cost at iteration 83600:0.014236
# Cost at iteration 83700:0.014219
# Cost at iteration 83800:0.014202
# Cost at iteration 83900:0.014184
# Cost at iteration 84000:0.014167
# Cost at iteration 84100:0.014150
# Cost at iteration 84200:0.014133
# Cost at iteration 84300:0.014116
# Cost at iteration 84400:0.014099
# Cost at iteration 84500:0.014082
# Cost at iteration 84600:0.014065
# Cost at iteration 84700:0.014049
# Cost at iteration 84800:0.014032
# Cost at iteration 84900:0.014015
# Cost at iteration 85000:0.013998
# Cost at iteration 85100:0.013982
# Cost at iteration 85200:0.013965
# Cost at iteration 85300:0.013948
# Cost at iteration 85400:0.013932
# Cost at iteration 85500:0.013915
# Cost at iteration 85600:0.013899
# Cost at iteration 85700:0.013882
# Cost at iteration 85800:0.013866
# Cost at iteration 85900:0.013849
# Cost at iteration 86000:0.013833
# Cost at iteration 86100:0.013817
# Cost at iteration 86200:0.013801
# Cost at iteration 86300:0.013784
# Cost at iteration 86400:0.013768
# Cost at iteration 86500:0.013752
# Cost at iteration 86600:0.013736
# Cost at iteration 86700:0.013720
# Cost at iteration 86800:0.013704
# Cost at iteration 86900:0.013688
# Cost at iteration 87000:0.013672
# Cost at iteration 87100:0.013656
# Cost at iteration 87200:0.013640
# Cost at iteration 87300:0.013624
# Cost at iteration 87400:0.013608
# Cost at iteration 87500:0.013592
# Cost at iteration 87600:0.013577
# Cost at iteration 87700:0.013561
# Cost at iteration 87800:0.013545
# Cost at iteration 87900:0.013530
# Cost at iteration 88000:0.013514
# Cost at iteration 88100:0.013499
# Cost at iteration 88200:0.013483
# Cost at iteration 88300:0.013468
# Cost at iteration 88400:0.013452
# Cost at iteration 88500:0.013437
# Cost at iteration 88600:0.013421
# Cost at iteration 88700:0.013406
# Cost at iteration 88800:0.013391
# Cost at iteration 88900:0.013375
# Cost at iteration 89000:0.013360
# Cost at iteration 89100:0.013345
# Cost at iteration 89200:0.013330
# Cost at iteration 89300:0.013314
# Cost at iteration 89400:0.013299
# Cost at iteration 89500:0.013284
# Cost at iteration 89600:0.013269
# Cost at iteration 89700:0.013254
# Cost at iteration 89800:0.013239
# Cost at iteration 89900:0.013224
# Cost at iteration 90000:0.013209
# Cost at iteration 90100:0.013194
# Cost at iteration 90200:0.013180
# Cost at iteration 90300:0.013165
# Cost at iteration 90400:0.013150
# Cost at iteration 90500:0.013135
# Cost at iteration 90600:0.013121
# Cost at iteration 90700:0.013106
# Cost at iteration 90800:0.013091
# Cost at iteration 90900:0.013077
# Cost at iteration 91000:0.013062
# Cost at iteration 91100:0.013047
# Cost at iteration 91200:0.013033
# Cost at iteration 91300:0.013018
# Cost at iteration 91400:0.013004
# Cost at iteration 91500:0.012990
# Cost at iteration 91600:0.012975
# Cost at iteration 91700:0.012961
# Cost at iteration 91800:0.012946
# Cost at iteration 91900:0.012932
# Cost at iteration 92000:0.012918
# Cost at iteration 92100:0.012904
# Cost at iteration 92200:0.012889
# Cost at iteration 92300:0.012875
# Cost at iteration 92400:0.012861
# Cost at iteration 92500:0.012847
# Cost at iteration 92600:0.012833
# Cost at iteration 92700:0.012819
# Cost at iteration 92800:0.012805
# Cost at iteration 92900:0.012791
# Cost at iteration 93000:0.012777
# Cost at iteration 93100:0.012763
# Cost at iteration 93200:0.012749
# Cost at iteration 93300:0.012735
# Cost at iteration 93400:0.012721
# Cost at iteration 93500:0.012708
# Cost at iteration 93600:0.012694
# Cost at iteration 93700:0.012680
# Cost at iteration 93800:0.012666
# Cost at iteration 93900:0.012653
# Cost at iteration 94000:0.012639
# Cost at iteration 94100:0.012625
# Cost at iteration 94200:0.012612
# Cost at iteration 94300:0.012598
# Cost at iteration 94400:0.012585
# Cost at iteration 94500:0.012571
# Cost at iteration 94600:0.012558
# Cost at iteration 94700:0.012544
# Cost at iteration 94800:0.012531
# Cost at iteration 94900:0.012517
# Cost at iteration 95000:0.012504
# Cost at iteration 95100:0.012491
# Cost at iteration 95200:0.012477
# Cost at iteration 95300:0.012464
# Cost at iteration 95400:0.012451
# Cost at iteration 95500:0.012437
# Cost at iteration 95600:0.012424
# Cost at iteration 95700:0.012411
# Cost at iteration 95800:0.012398
# Cost at iteration 95900:0.012385
# Cost at iteration 96000:0.012372
# Cost at iteration 96100:0.012359
# Cost at iteration 96200:0.012346
# Cost at iteration 96300:0.012333
# Cost at iteration 96400:0.012320
# Cost at iteration 96500:0.012307
# Cost at iteration 96600:0.012294
# Cost at iteration 96700:0.012281
# Cost at iteration 96800:0.012268
# Cost at iteration 96900:0.012255
# Cost at iteration 97000:0.012242
# Cost at iteration 97100:0.012229
# Cost at iteration 97200:0.012217
# Cost at iteration 97300:0.012204
# Cost at iteration 97400:0.012191
# Cost at iteration 97500:0.012178
# Cost at iteration 97600:0.012166
# Cost at iteration 97700:0.012153
# Cost at iteration 97800:0.012140
# Cost at iteration 97900:0.012128
# Cost at iteration 98000:0.012115
# Cost at iteration 98100:0.012103
# Cost at iteration 98200:0.012090
# Cost at iteration 98300:0.012078
# Cost at iteration 98400:0.012065
# Cost at iteration 98500:0.012053
# Cost at iteration 98600:0.012040
# Cost at iteration 98700:0.012028
# Cost at iteration 98800:0.012016
# Cost at iteration 98900:0.012003
# Cost at iteration 99000:0.011991
# Cost at iteration 99100:0.011979
# Cost at iteration 99200:0.011967
# Cost at iteration 99300:0.011954
# Cost at iteration 99400:0.011942
# Cost at iteration 99500:0.011930
# Cost at iteration 99600:0.011918
# Cost at iteration 99700:0.011906
# Cost at iteration 99800:0.011893
# Cost at iteration 99900:0.011881

# %%
print('w: ' + str(params['w']))
print('\n')
print('b: ' + str(params['b']))
print('\n')
print('dw: ' + str(grads['dw']))
print('\n')
print('db: ' + str(grads['db']))
print('\n')
print('cost: ' + str(costs[:5]))
# Out:
# w: [[-9.91808291]
#  [ 1.85209887]]
#
#
# b: 8.22904078373
#
#
# dw: [[ 0.00303429]
#  [-0.00075858]]
#
#
# db: -0.00189988690107
#
#
# cost: [5.8015453193945534, 1.055933444321741, 0.37830291814111128, 0.36359491114822828, 0.3562416177005574]

# %% [markdown]
# ## Predicting new results

# %%
def predict(w,b,X):
    m = X.shape[1]
    Y_pred = np.zeros(shape=(1,m))
    w = w.reshape(X.shape[0], 1)
    A = sigmoid(np.dot(w.T,X) + b)
    for i in range(A.shape[1]):
        Y_pred[0,i] = 1 if A[0,i] > 0.5 else 0
    return Y_pred

# %%
w = np.array([[0.1124579],[0.23106775]])
b = -0.3
X = np.array([[1.,-1.1,-3.2],[1.2,2.,0.1]])
predict = predict(w,b,X)

# %%
print("Predictions: " + str(predict))
# Out:
# Predictions: [[ 1.  1.  0.]]

# %% [markdown]
# ## Final Model

# %%
def model(X_train,Y_train,X_test,Y_test,num_iterations,learning_rate,print_cost=False):
    w,b = initialize_with_zeros(X_train.shape[0])
    
    grads,params,costs = optimize(w,b,X_train,Y_train,num_iterations,learning_rate,print_cost)
    
    w = params['w']
    b = params['b']
    
    print(w)
    print("\n")
    print(b)
    Y_prediction_test = predict(w,b,X_test)
    Y_prediction_train = predict(w,b,X_train)
    
    print("Train accuracy: " + str(100 - np.mean(np.abs(Y_prediction_train-Y_train))*100))
    print("Test accuracy: " + str(100 - np.mean(np.abs(Y_prediction_train-Y_train))*100))
    
    d = {'w':w,
         'b':b,
         'learning_rate':learning_rate,
         'costs':costs
            } 
    return d

# %%
X_train, Y_train = np.array([[1.,2.,-1.],[3.,4.,-3.2]]), np.array([[1,0,1]])
X_test,Y_test =  np.array([[1.,2.,-1.],[3.,4.,-3.2]]), np.array([[1,0,1]])
learning_rate = 0.001
num_iterations = 10000
d = model(X_train,Y_train,X_test,Y_test,num_iterations,learning_rate,print_cost=True)
# Out:
# Cost at iteration 0:0.693147
# Cost at iteration 100:0.645976
# Cost at iteration 200:0.619210
# Cost at iteration 300:0.602660
# Cost at iteration 400:0.591353
# Cost at iteration 500:0.582829
# Cost at iteration 600:0.575844
# Cost at iteration 700:0.569752
# Cost at iteration 800:0.564212
# Cost at iteration 900:0.559036
# Cost at iteration 1000:0.554122
# Cost at iteration 1100:0.549410
# Cost at iteration 1200:0.544867
# Cost at iteration 1300:0.540469
# Cost at iteration 1400:0.536204
# Cost at iteration 1500:0.532062
# Cost at iteration 1600:0.528035
# Cost at iteration 1700:0.524117
# Cost at iteration 1800:0.520303
# Cost at iteration 1900:0.516588
# Cost at iteration 2000:0.512968
# Cost at iteration 2100:0.509440
# Cost at iteration 2200:0.506000
# Cost at iteration 2300:0.502643
# Cost at iteration 2400:0.499368
# Cost at iteration 2500:0.496170
# Cost at iteration 2600:0.493047
# Cost at iteration 2700:0.489996
# Cost at iteration 2800:0.487014
# Cost at iteration 2900:0.484098
# Cost at iteration 3000:0.481247
# Cost at iteration 3100:0.478458
# Cost at iteration 3200:0.475728
# Cost at iteration 3300:0.473055
# Cost at iteration 3400:0.470438
# Cost at iteration 3500:0.467874
# Cost at iteration 3600:0.465361
# Cost at iteration 3700:0.462898
# Cost at iteration 3800:0.460483
# Cost at iteration 3900:0.458114
# Cost at iteration 4000:0.455790
# Cost at iteration 4100:0.453508
# Cost at iteration 4200:0.451269
# Cost at iteration 4300:0.449070
# Cost at iteration 4400:0.446910
# Cost at iteration 4500:0.444787
# Cost at iteration 4600:0.442701
# Cost at iteration 4700:0.440650
# Cost at iteration 4800:0.438634
# Cost at iteration 4900:0.436651
# Cost at iteration 5000:0.434700
# Cost at iteration 5100:0.432779
# Cost at iteration 5200:0.430889
# Cost at iteration 5300:0.429029
# Cost at iteration 5400:0.427197
# Cost at iteration 5500:0.425392
# Cost at iteration 5600:0.423614
# Cost at iteration 5700:0.421862
# Cost at iteration 5800:0.420135
# Cost at iteration 5900:0.418433
# Cost at iteration 6000:0.416754
# Cost at iteration 6100:0.415099
# Cost at iteration 6200:0.413466
# Cost at iteration 6300:0.411855
# Cost at iteration 6400:0.410265
# Cost at iteration 6500:0.408696
# Cost at iteration 6600:0.407147
# Cost at iteration 6700:0.405618
# Cost at iteration 6800:0.404108
# Cost at iteration 6900:0.402617
# Cost at iteration 7000:0.401144
# Cost at iteration 7100:0.399688
# Cost at iteration 7200:0.398250
# Cost at iteration 7300:0.396829
# Cost at iteration 7400:0.395424
# Cost at iteration 7500:0.394035
# Cost at iteration 7600:0.392662
# Cost at iteration 7700:0.391304
# Cost at iteration 7800:0.389961
# Cost at iteration 7900:0.388633
# Cost at iteration 8000:0.387319
# Cost at iteration 8100:0.386019
# Cost at iteration 8200:0.384732
# Cost at iteration 8300:0.383459
# Cost at iteration 8400:0.382198
# Cost at iteration 8500:0.380951
# Cost at iteration 8600:0.379716
# Cost at iteration 8700:0.378493
# Cost at iteration 8800:0.377282
# Cost at iteration 8900:0.376082
# Cost at iteration 9000:0.374895
# Cost at iteration 9100:0.373718
# Cost at iteration 9200:0.372552
# Cost at iteration 9300:0.371397
# Cost at iteration 9400:0.370253
# Cost at iteration 9500:0.369119
# Cost at iteration 9600:0.367995
# Cost at iteration 9700:0.366880
# Cost at iteration 9800:0.365776
# Cost at iteration 9900:0.364681
# [[-0.71055561]
#  [-0.18664684]]
#
#
# 1.33681250104
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-74a9d2b38fdc> in <module>()
#       3 learning_rate = 0.001
#       4 num_iterations = 10000
# ----> 5 d = model(X_train,Y_train,X_test,Y_test,num_iterations,learning_rate,print_cost=True)
#
# <ipython-input-49-55a80eccb9ea> in model(X_train, Y_train, X_test, Y_test, num_iterations, learning_rate, print_cost)
#      10     print("\n")
#      11     print(b)
# ---> 12     Y_prediction_test = predict(w,b,X_test)
#      13     Y_prediction_train = predict(w,b,X_train)
#      14
#
# TypeError: 'numpy.ndarray' object is not callable
